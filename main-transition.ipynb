# %% [markdown]
# >[Load Data - Colab](#scrollTo=NUI5kbcWownP)
#
# >[Initiate](#scrollTo=rp-VpVt8PeQR)
#
# >[Preprocessing](#scrollTo=GF3n7POppx8u)
#
# >>[Create same size slices](#scrollTo=kC6RHcbEvfGi)
#
# >>[Augmentation](#scrollTo=aYgfdiKmPeQl)
#
# >[Transform images](#scrollTo=fvjy5Nchv6AA)
#
# >>[check data transformations](#scrollTo=VGEt2rzUrGKH)
#
# >[Train images](#scrollTo=RwFDZ-rn-JCy)
#
# >>[Functions for training](#scrollTo=76WXT37uBUSk)
#
# >>[Training](#scrollTo=WIyDq5MmBjKU)
#
# >>>[UNet](#scrollTo=4kUHZdHiPeQ9)
#
# >>>[Unet 3+](#scrollTo=-5K7WElk4Mkw)
#
# >>>[ModifiedNet](#scrollTo=atHxa7iJPeRE)
#
# >[Testing](#scrollTo=ZDtWeaxR1rpV)
#
# >>[UNet](#scrollTo=-Xn_PtG_rGKS)
#
# >>[Modified Net](#scrollTo=fzwqirRrrGKT)
#
# >>[UNet 3+](#scrollTo=xdh-l32hrGKV)
#
# >[Plot](#scrollTo=aXi-FpGXrGKW)

# %% [markdown]
# # Load Data - Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#for colab
# %cd "/content/drive/MyDrive/Prostate"
# Out:
# /content/drive/MyDrive/Prostate

# %% [markdown]
# # Initiate

# %%
HOME_DIR =       "./"
DATA_DIR =       "./PROSTATEx_masks/Files/prostate/"
OUT_DIR =        "./results/transition/"
SLICED_OUT_DIR = "./data/sliced/prostate/"
AUG_OUT_DIR = "./data/augmented/prostate/"

# %%
import os
from glob import glob
import shutil
from tqdm import tqdm
import dicom2nifti
import numpy as np
import nibabel as nib
import pandas as pd
from monai.utils import first

import json
import matplotlib.pyplot as plt
# %matplotlib inline
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
import os

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Create same size slices
# create new nifti images with 16 slices and save

# %%
df = pd.read_csv(DATA_DIR +'image_list.csv')

# %%
# ignore
df.tail()
# Out:
#                               T2
# 199  ProstateX-0199_t2_tse_tra_4
# 200  ProstateX-0200_t2_tse_tra_7
# 201  ProstateX-0201_t2_tse_tra_4
# 202  ProstateX-0202_t2_tse_tra_4
# 203  ProstateX-0203_t2_tse_tra_4

# %%
def makeLabelNo(name):
  numb= name.split("-")[1]
  li=[80,81,83,85,86,87,88,89,90,91,93,96,98]
  if(int(numb) in li):
    return 'ProstateX-' + numb[1:]
  if (int(numb) in [202,203]):
    return 'VOLUME-'+ numb
  return name

# %%
data = [{'image': DATA_DIR + 'Images/' + x + ".nii.gz", "label":DATA_DIR + 'mask_tz/' + makeLabelNo(x.split("_")[0])+'_tz' + ".nii.gz"  } for x in df['T2']]

# %%
# ignore
l=[]
for i in data:
  image = nib.load(i["image"])
  # label = nib.load(i["label"])
  # print(image.shape, label.shape)
  l.append(image.shape[2])
print(min(l),max(l))
# Out:
# 18 27

# %%
slice_size=16

# %%
if not os.path.exists(SLICED_OUT_DIR + "mask_tz"):
    os.makedirs(SLICED_OUT_DIR + "mask_tz")

# %%
from utils.preprocessing import create_same_slice_zone

create_same_slice_zone(data, slice_size , SLICED_OUT_DIR + 'config_tz.json')
# Out:
# 1/204
# 2/204
# 3/204
# 4/204
# 5/204
# 6/204
# 7/204
# 8/204
# 9/204
# 10/204
# 11/204
# 12/204
# 13/204
# 14/204
# 15/204
# 16/204
# 17/204
# 18/204
# 19/204
# 20/204
# 21/204
# 22/204
# 23/204
# 24/204
# 25/204
# 26/204
# 27/204
# 28/204
# 29/204
# 30/204
# 31/204
# 32/204
# 33/204
# 34/204
# 35/204
# 36/204
# 37/204
# 38/204
# 39/204
# 40/204
# 41/204
# 42/204
# 43/204
# 44/204
# 45/204
# 46/204
# 47/204
# 48/204
# 49/204
# 50/204
# 51/204
# 52/204
# 53/204
# 54/204
# 55/204
# 56/204
# 57/204
# 58/204
# 59/204
# 60/204
# 61/204
# 62/204
# 63/204
# 64/204
# 65/204
# 66/204
# 67/204
# 68/204
# 69/204
# 70/204
# 71/204
# 72/204
# 73/204
# 74/204
# 75/204
# 76/204
# 77/204
# 78/204
# 79/204
# 80/204
# 81/204
# 82/204
# 83/204
# 84/204
# 85/204
# 86/204
# 87/204
# 88/204
# 89/204
# 90/204
# 91/204
# 92/204
# 93/204
# 94/204
# 95/204
# 96/204
# 97/204
# 98/204
# 99/204
# 100/204
# 101/204
# 102/204
# 103/204
# 104/204
# 105/204
# 106/204
# 107/204
# 108/204
# 109/204
# 110/204
# 111/204
# 112/204
# 113/204
# 114/204
# 115/204
# 116/204
# 117/204
# 118/204
# 119/204
# 120/204
# 121/204
# 122/204
# 123/204
# 124/204
# 125/204
# 126/204
# 127/204
# 128/204
# 129/204
# 130/204
# 131/204
# 132/204
# 133/204
# 134/204
# 135/204
# 136/204
# 137/204
# 138/204
# 139/204
# 140/204
# 141/204
# 142/204
# 143/204
# 144/204
# 145/204
# 146/204
# 147/204
# 148/204
# 149/204
# 150/204
# 151/204
# 152/204
# 153/204
# 154/204
# 155/204
# 156/204
# 157/204
# 158/204
# 159/204
# 160/204
# 161/204
# 162/204
# 163/204
# 164/204
# 165/204
# 166/204
# 167/204
# 168/204
# 169/204
# 170/204
# 171/204
# 172/204
# 173/204
# 174/204
# 175/204
# 176/204
# 177/204
# 178/204
# 179/204
# 180/204
# 181/204
# 182/204
# 183/204
# 184/204
# 185/204
# 186/204
# 187/204
# 188/204
# 189/204
# 190/204
# 191/204
# 192/204
# 193/204
# 194/204
# 195/204
# 196/204
# 197/204
# 198/204
# 199/204
# 200/204
# 201/204
# 202/204
# 203/204
# 204/204

# %% [markdown]
# ## Augmentation

# %%
def get_data_path(path):
  f = open( path + 'config_pz.json')
  jdata = json.load(f)
  f.close()
  return jdata["path"]

# %%
data = get_data_path(SLICED_OUT_DIR)

# %%
from Augmentation.augmentation import verticalFlip, horizontalFlip, rotate, noise, elasticDeformation


types = { 'verticalFliped': verticalFlip, 'horizontalFliped' : horizontalFlip, 'rotated':rotate, 'noised':noise, 'deformed': elasticDeformation}

for type,func in types.items():
    # create directries if does not exist
    if not os.path.exists(AUG_OUT_DIR + type ):
        os.makedirs(AUG_OUT_DIR + type)
    if not os.path.exists(AUG_OUT_DIR + type + "/Images"):
        os.makedirs(AUG_OUT_DIR + type + "/Images")
    if not os.path.exists(AUG_OUT_DIR + type + "/mask_pz"):
        os.makedirs(AUG_OUT_DIR + type + "/mask_pz")

# %%
from utils.preprocessing import load_nifti

def augment(func, entry, name, paths):
    img, lbl = load_nifti(entry["image"], entry["label"])
    
    image, label = func(img, lbl)
    image_path = entry["image"].replace("data/sliced/prostate", "data/augmented/prostate/" + name)
    label_path = entry["label"].replace("data/sliced/prostate", "data/augmented/prostate/" + name)
    paths.append({"image":image_path, "label":label_path})
    #image.to_filename(image_path )
    label.to_filename(label_path)

# %%
from utils.preprocessing import save_to_json

paths = []
for type, func in types.items():
    #create augmented data
    
    for entry in data:
        augment(func, entry, type, paths)
        break
   
save_to_json({"path": paths}, AUG_OUT_DIR + '/config_tz.json')

# %%
# x = data + paths
# len(x)
# Out:
# 209

# %% [markdown]
# # Transform images

# %%
def get_data_path(path):
  f = open( path + 'config_tz.json')
  jdata = json.load(f)
  f.close()
  return jdata["path"]

# %%
data = get_data_path(SLICED_OUT_DIR)
aug_data = get_data_path(AUG_OUT_DIR)

data = data + aug_data
print(len(data))

train_size = int(0.8 * len(data))
train_data, test_data = data[:train_size], data[train_size:]
# Out:
# 209

# %%
pixdim =(1.5, 1.5, 1.0)
a_min=0
a_max=500
spatial_size= [128, 128,16] #[384, 384,18]

# %%
from utils.transform import transform

train_loader = transform(train_data, a_min, a_max, spatial_size, pixdim)
test_loader = transform(test_data, a_min, a_max, spatial_size, pixdim)
# Out:
# c:\Users\envy\Desktop\Prostate_MRI\Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\monai\utils\deprecate_utils.py:107: FutureWarning: <class 'monai.transforms.utility.array.AddChannel'>: Class `AddChannel` has been deprecated since version 0.8. please use MetaTensor data type and monai.transforms.EnsureChannelFirst instead.
#   warn_deprecated(obj, msg, warning_category)

# %% [markdown]
# ## check data transformations

# %%
# first image, label from orignal image
imagea =nib.load(data[0]["image"]).get_fdata()
labela =nib.load(data[0]["label"]).get_fdata()
print(imagea.shape,labela.shape)
# Out:
# (384, 384, 16) (384, 384, 16)

# %%
# first image, label from preprossed image
image1= first(train_loader)["image"]
label1 = first(train_loader)["label"]
print(image1.shape,label1.shape)
image11 =image1.get_array()
label11 = label1.get_array()
# Out:
# torch.Size([1, 1, 128, 128, 16]) torch.Size([1, 1, 128, 128, 16])

# %%
# Define a function to visualize the data
def explore_3dimage(layer):
    plt.figure(figsize=(10, 5))
    channel = 2
    # plt.imshow(image11[0,0,:,:,layer], cmap='gray');
    # plt.title('Explore Layers of Prostate MRI', fontsize=20)
    # plt.axis('off')
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

    ax[0].imshow(imagea[:,:,layer], cmap='gray')
    ax[0].set_title(f"Image", fontsize=15)
    ax[0].axis('off')

    ax[1].imshow(labela[:,:,layer])
    ax[1].axis('off')
    return layer

# %%
# Explore the preprocessed image, label
interact(explore_3dimage, layer=(0, 18))
# Out:
# interactive(children=(IntSlider(value=9, description='layer', max=18), Output()), _dom_classes=('widget-intera…
# <function __main__.explore_3dimage(layer)>

# %%
# Define a function to visualize the data
def explore_3dimage2(layer):
    plt.figure(figsize=(10, 5))
    channel = 2
    # plt.imshow(image11[0,0,:,:,layer], cmap='gray');
    # plt.title('Explore Layers of Prostate MRI', fontsize=20)
    # plt.axis('off')
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

    ax[0].imshow(image1[0,0,:,:,layer], cmap='gray')
    ax[0].set_title(f"Image", fontsize=15)
    ax[0].axis('off')

    ax[1].imshow(label1[0,0,:,:,layer])
    ax[1].axis('off')
    return

# %%
# Explore the preprocessed image, label
interact(explore_3dimage, layer=(0, 16))
# Out:
# interactive(children=(IntSlider(value=8, description='layer', max=16), Output()), _dom_classes=('widget-intera…
# <function __main__.explore_3dimage(layer)>

# %% [markdown]
# # Train images

# %% [markdown]
# ## Functions for training

# %%
from monai.utils import first
import matplotlib.pyplot as plt
import torch
import os
import numpy as np
from monai.losses import DiceLoss
from tqdm import tqdm
from utils.train import train

# %% [markdown]
# ## Training

# %%
model_dir = OUT_DIR 
data_in = [train_loader, test_loader]

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### UNet

# %%
from monai.networks.nets import UNet
from monai.networks.layers import Norm

unet = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=1,
    channels=( 64, 128, 256,512), 
    strides=(2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

# %%
#loss_function = DiceCELoss(to_onehot_y=True, sigmoid=True, squared_pred=True, ce_weight=calculate_weights(1792651250,2510860).to(device))
loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(unet.parameters(), 1e-5, weight_decay=1e-5, amsgrad=True)

# %%
model_dir = OUT_DIR + "unet/"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
import os.path

path = OUT_DIR+ "unet/"+ "best_metric_model.pth"

if (os.path.exists(path)):
    unet.load_state_dict(torch.load(
        os.path.join(path)))

# %%
train(unet, data_in, loss_function, optimizer, 2, model_dir, test_interval=1,start_from=1)
# Out:
# ----------
# epoch 1/2
# c:\Users\envy\Desktop\Prostate_MRI\Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\monai\losses\dice.py:144: UserWarning: single channel prediction, `to_onehot_y=True` ignored.
#   warnings.warn("single channel prediction, `to_onehot_y=True` ignored.")
# 1/167, Train_loss: 0.9583 Train_dice: 0.0417
# 2/167, Train_loss: 0.9600 Train_dice: 0.0400
# 3/167, Train_loss: 0.9765 Train_dice: 0.0235
# 4/167, Train_loss: 0.8044 Train_dice: 0.1956
# 5/167, Train_loss: 0.8601 Train_dice: 0.1399
# 6/167, Train_loss: 0.9631 Train_dice: 0.0369
# 7/167, Train_loss: 0.9022 Train_dice: 0.0978
# 8/167, Train_loss: 0.8844 Train_dice: 0.1156
# 9/167, Train_loss: 0.9076 Train_dice: 0.0924
# 10/167, Train_loss: 0.8777 Train_dice: 0.1223
# 11/167, Train_loss: 0.9667 Train_dice: 0.0333
# 12/167, Train_loss: 0.9677 Train_dice: 0.0323
# 13/167, Train_loss: 0.9441 Train_dice: 0.0559
# 14/167, Train_loss: 0.8809 Train_dice: 0.1191
# 15/167, Train_loss: 0.9672 Train_dice: 0.0328
# 150/167, Train_loss: 0.9389 Train_dice: 0.0611
# 151/167, Train_loss: 0.8588 Train_dice: 0.1412
# 152/167, Train_loss: 0.7217 Train_dice: 0.2783
# 153/167, Train_loss: 0.9213 Train_dice: 0.0787
# 154/167, Train_loss: 0.8559 Train_dice: 0.1441
# 155/167, Train_loss: 0.7506 Train_dice: 0.2494
# 156/167, Train_loss: 0.8379 Train_dice: 0.1621
# 157/167, Train_loss: 0.7327 Train_dice: 0.2673
# 158/167, Train_loss: 0.9228 Train_dice: 0.0772
# 159/167, Train_loss: 0.8475 Train_dice: 0.1525
# 160/167, Train_loss: 0.8398 Train_dice: 0.1602
# 161/167, Train_loss: 0.8790 Train_dice: 0.1210
# 162/167, Train_loss: 0.6925 Train_dice: 0.3075
# 163/167, Train_loss: 0.7249 Train_dice: 0.2751
# 164/167, Train_loss: 0.6437 Train_dice: 0.3563
# 165/167, Train_loss: 0.9512 Train_dice: 0.0488
# 166/167, Train_loss: 0.8548 Train_dice: 0.1452
# 167/167, Train_loss: 0.8480 Train_dice: 0.1520
# --------------------
# Epoch_loss: 0.8315
# Epoch_metric: 0.1685
# test_loss_epoch: 0.8671
# test_dice_epoch: 0.1396
# current epoch: 2 current mean dice: 0.5539
# best mean dice: 0.1396 at epoch: 2
# Time Taken:  598.1929821968079
# Maximum GPU Memory taken for training:  0
# Maximum CPU Memory taken for training:  320
# train completed, best_metric: 0.1396 at epoch: 2

# %% [markdown]
# ### Unet 3+

# %%
from Models.Unet_TriplePlus import U_net_TriplePlus

unet_3plus =  U_net_TriplePlus(1,1).to(device)

# %%
#loss_function = DiceCELoss(to_onehot_y=True, sigmoid=True, squared_pred=True, ce_weight=calculate_weights(1792651250,2510860).to(device))
loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(unet_3plus.parameters(), 1e-5, weight_decay=1e-5, amsgrad=True)

# %%
model_dir = OUT_DIR + "/unet_3plus/"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
import os.path

path = OUT_DIR+ "unet_3plus/"+ "best_metric_model.pth"
print(path)
if (os.path.exists(path)):
    unet.load_state_dict(torch.load(
        os.path.join(path)))
# Out:
# ./results/unet_3plus/best_metric_model.pth

# %%
train(unet_3plus, data_in, loss_function, optimizer, 2, model_dir, test_interval=1,start_from=1)
# Out:
# ----------
# epoch 1/2
# shape torch.Size([1, 1, 128, 128, 16])
# c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\monai\losses\dice.py:144: UserWarning: single channel prediction, `to_onehot_y=True` ignored.
#   warnings.warn("single channel prediction, `to_onehot_y=True` ignored.")
# 1/167, Train_loss: 0.8627 Train_dice: 0.1373
# shape torch.Size([1, 1, 128, 128, 16])
# 2/167, Train_loss: 0.9036 Train_dice: 0.0964
# shape torch.Size([1, 1, 128, 128, 16])
# 3/167, Train_loss: 0.8710 Train_dice: 0.1290
# shape torch.Size([1, 1, 128, 128, 16])
# 4/167, Train_loss: 0.7247 Train_dice: 0.2753
# shape torch.Size([1, 1, 128, 128, 16])
# shape torch.Size([1, 1, 128, 128, 16])
# 34/167, Train_loss: 0.5190 Train_dice: 0.4810
# shape torch.Size([1, 1, 128, 128, 16])
# 35/167, Train_loss: 0.6121 Train_dice: 0.3879
# shape torch.Size([1, 1, 128, 128, 16])
# 36/167, Train_loss: 0.5061 Train_dice: 0.4939
# shape torch.Size([1, 1, 128, 128, 16])
# 37/167, Train_loss: 0.5709 Train_dice: 0.4291
# shape torch.Size([1, 1, 128, 128, 16])
# 38/167, Train_loss: 0.7408 Train_dice: 0.2592
# shape torch.Size([1, 1, 128, 128, 16])
# 39/167, Train_loss: 0.6231 Train_dice: 0.3769
# shape torch.Size([1, 1, 128, 128, 16])
# 40/167, Train_loss: 0.5543 Train_dice: 0.4457
# shape torch.Size([1, 1, 128, 128, 16])
# 41/167, Train_loss: 0.6489 Train_dice: 0.3511
# shape torch.Size([1, 1, 128, 128, 16])
# 42/167, Train_loss: 0.6067 Train_dice: 0.3933
# shape torch.Size([1, 1, 128, 128, 16])
# 43/167, Train_loss: 0.5321 Train_dice: 0.4679
# shape torch.Size([1, 1, 128, 128, 16])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 train(unet_3plus, data_in, loss_function, optimizer, 2, model_dir, test_interval=1,start_from=1)
#
# Cell In[85], line 42, in train(model, data_in, loss, optim, max_epochs, model_dir, test_interval, device, start_from, model_name)
#      40 optim.zero_grad()
#      41 print("shape", volume.shape)
# ---> 42 outputs = model(volume)
#      44 train_loss = loss(outputs, label)
#      46 train_loss.backward()
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\Models\Unet_TriplePlus.py:521, in U_net_TriplePlus.forward(self, x)
#     518 x8_6 = torch.cat((x8_1,x8_2,x8_3,x8_4,x8_5),1)
#     519 x8 = self.de3_6(x8_6)
# --> 521 x9_1 = self.de4_1(x5)
#     522 x9_2 = self.de4_2(x6)
#     523 x9_3 = self.de4_3(x7)
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\Models\Unet_TriplePlus.py:223, in Up_conv.forward(self, x)
#     222 def forward(self,x):
# --> 223     x = self.up(x)
#     224     x = self.conv(x)
#     225     return x
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\torch\nn\modules\upsampling.py:156, in Upsample.forward(self, input)
#     155 def forward(self, input: Tensor) -> Tensor:
# --> 156     return F.interpolate(input, self.size, self.scale_factor, self.mode, self.align_corners,
#     157                          recompute_scale_factor=self.recompute_scale_factor)
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\torch\nn\functional.py:3834, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    3773 r"""Down/up samples the input to either the given :attr:`size` or the given
#    3774 :attr:`scale_factor`
#    3775
#    (...)
#    3831     {backward_reproducibility_note}
#    3832 """
#    3833 if has_torch_function_unary(input):
# -> 3834     return handle_torch_function(
#    3835         interpolate,
#    3836         (input,),
#    3837         input,
#    3838         size=size,
#    3839         scale_factor=scale_factor,
#    3840         mode=mode,
#    3841         align_corners=align_corners,
#    3842         recompute_scale_factor=recompute_scale_factor,
#    3843         antialias=antialias
#    3844     )
#    3846 if mode in ("nearest", "area", "nearest-exact"):
#    3847     if align_corners is not None:
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\torch\overrides.py:1551, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1545     warnings.warn("Defining your `__torch_function__ as a plain method is deprecated and "
#    1546                   "will be an error in future, please define it as a classmethod.",
#    1547                   DeprecationWarning)
#    1549 # Use `public_api` instead of `implementation` so __torch_function__
#    1550 # implementations can do equality/identity comparisons.
# -> 1551 result = torch_func_method(public_api, types, args, kwargs)
#    1553 if result is not NotImplemented:
#    1554     return result
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\monai\data\meta_tensor.py:268, in MetaTensor.__torch_function__(cls, func, types, args, kwargs)
#     266 if kwargs is None:
#     267     kwargs = {}
# --> 268 ret = super().__torch_function__(func, types, args, kwargs)
#     269 # if `out` has been used as argument, metadata is not copied, nothing to do.
#     270 # if "out" in kwargs:
#     271 #     return ret
#     272 if _not_requiring_metadata(ret):
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\torch\_tensor.py:1295, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    1292     return NotImplemented
#    1294 with _C.DisableTorchFunctionSubclass():
# -> 1295     ret = func(*args, **kwargs)
#    1296     if func in get_default_nowrap_functions():
#    1297         return ret
#
# File c:\Users\envy\Desktop\Prostate_MRI\-Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\torch\nn\functional.py:3962, in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor, antialias)
#    3960 if input.dim() == 5 and mode == "trilinear":
#    3961     assert align_corners is not None
# -> 3962     return torch._C._nn.upsample_trilinear3d(input, output_size, align_corners, scale_factors)
#    3963 if input.dim() == 4 and mode == "bicubic":
#    3964     assert align_corners is not None
#
# KeyboardInterrupt:

# %% [markdown]
# ### ModifiedNet

# %%
from Models.ModifiedNet import MNet

mnet = MNet().to(device)

# %%
#loss_function = DiceCELoss(to_onehot_y=True, sigmoid=True, squared_pred=True, ce_weight=calculate_weights(1792651250,2510860).to(device))
loss_function = DiceLoss(to_onehot_y=True, sigmoid=True, squared_pred=True)
optimizer = torch.optim.Adam(mnet.parameters(), 1e-5, weight_decay=1e-5, amsgrad=True)

# %%
model_dir = OUT_DIR + "mnet/"
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
import os.path

path = OUT_DIR+ "mnet/"+ "best_metric_model.pth"
print(path)
if (os.path.exists(path)):
    unet.load_state_dict(torch.load(
        os.path.join(OUT_DIR+ "mnet"+ "/best_metric_model.pth")))
# Out:
# ./results/mnet/best_metric_model.pth

# %%
train(mnet, data_in, loss_function, optimizer, 2, model_dir, test_interval=1,start_from=1)
# Out:
# ----------
# epoch 1/2
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# c:\Users\envy\Desktop\Prostate_MRI\Prostate_MRI_Detection_3D_Model\packages\lib\site-packages\monai\losses\dice.py:144: UserWarning: single channel prediction, `to_onehot_y=True` ignored.
#   warnings.warn("single channel prediction, `to_onehot_y=True` ignored.")
# 1/167, Train_loss: 0.9032 Train_dice: 0.0968
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 2/167, Train_loss: 0.9246 Train_dice: 0.0754
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 3/167, Train_loss: 0.9342 Train_dice: 0.0658
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 4/167, Train_loss: 0.7676 Train_dice: 0.2324
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 5/167, Train_loss: 0.8034 Train_dice: 0.1966
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 6/167, Train_loss: 0.9149 Train_dice: 0.0851
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 7/167, Train_loss: 0.8670 Train_dice: 0.1330
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 8/167, Train_loss: 0.8349 Train_dice: 0.1651
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 9/167, Train_loss: 0.8769 Train_dice: 0.1231
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 10/167, Train_loss: 0.8489 Train_dice: 0.1511
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 11/167, Train_loss: 0.9195 Train_dice: 0.0805
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 12/167, Train_loss: 0.9269 Train_dice: 0.0731
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 13/167, Train_loss: 0.8885 Train_dice: 0.1115
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 14/167, Train_loss: 0.8296 Train_dice: 0.1704
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 15/167, Train_loss: 0.9386 Train_dice: 0.0614
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 16/167, Train_loss: 0.8699 Train_dice: 0.1301
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 17/167, Train_loss: 0.8112 Train_dice: 0.1888
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 18/167, Train_loss: 0.9271 Train_dice: 0.0729
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 19/167, Train_loss: 0.8713 Train_dice: 0.1287
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 20/167, Train_loss: 0.9095 Train_dice: 0.0905
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 21/167, Train_loss: 0.8611 Train_dice: 0.1389
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 22/167, Train_loss: 0.8740 Train_dice: 0.1260
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 23/167, Train_loss: 0.8486 Train_dice: 0.1514
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 24/167, Train_loss: 0.9149 Train_dice: 0.0851
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 25/167, Train_loss: 0.8853 Train_dice: 0.1147
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 26/167, Train_loss: 0.8209 Train_dice: 0.1791
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 27/167, Train_loss: 0.8677 Train_dice: 0.1323
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 28/167, Train_loss: 0.8070 Train_dice: 0.1930
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 29/167, Train_loss: 0.8846 Train_dice: 0.1154
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 30/167, Train_loss: 0.8521 Train_dice: 0.1479
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 31/167, Train_loss: 0.9312 Train_dice: 0.0688
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 32/167, Train_loss: 0.9057 Train_dice: 0.0943
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 33/167, Train_loss: 0.8254 Train_dice: 0.1746
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 34/167, Train_loss: 0.8601 Train_dice: 0.1399
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 35/167, Train_loss: 0.8563 Train_dice: 0.1437
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 36/167, Train_loss: 0.8393 Train_dice: 0.1607
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 37/167, Train_loss: 0.8428 Train_dice: 0.1572
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 38/167, Train_loss: 0.9130 Train_dice: 0.0870
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 39/167, Train_loss: 0.8874 Train_dice: 0.1126
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 40/167, Train_loss: 0.8068 Train_dice: 0.1932
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 41/167, Train_loss: 0.8699 Train_dice: 0.1301
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 42/167, Train_loss: 0.8429 Train_dice: 0.1571
# shape torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
#
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 18
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 19
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 20
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 21
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 22
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 23
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 24
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 25
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 26
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 27
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 28
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 29
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 30
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 31
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 32
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 33
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 34
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 35
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 36
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 37
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 38
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 39
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 40
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 41
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 42
# torch.Size([1, 1, 128, 128, 16])
# torch.Size([1, 512, 16, 16, 2]) torch.Size([1, 512, 16, 16, 2])
# 42
# test_loss_epoch: 0.4441
# test_dice_epoch: 0.4694
# current epoch: 2 current mean dice: 0.0233
# best mean dice: 0.4694 at epoch: 2
# 5194.664139032364
# 0.0
# 893.49
# train completed, best_metric: 0.4694 at epoch: 2

# %% [markdown]
# # Testing

# %%
from monai.utils import first
from monai.transforms import(
    Activations,
)

import matplotlib.pyplot as plt

import os
from glob import glob
import numpy as np

from monai.inferers import sliding_window_inference

# %%
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## UNet

# %%
from utils.view import  plt_metrices

path = OUT_DIR+ "unet/"
if (os.path.exists(path)):
    plt_metrices(path)

# %%
from monai.networks.nets import UNet
from monai.networks.layers import Norm


model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=1,
    channels=( 64, 128, 256,512), 
    strides=(2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

# %%
import os.path

path = OUT_DIR+ "unet/"+ "best_metric_model.pth"

if (os.path.exists(path)):
    model.load_state_dict(torch.load(
        os.path.join(path)))
# model.eval()

# %% [markdown]
# ## Modified Net

# %%
from utils.view import  plt_metrices

path = OUT_DIR+ "mnet/"
if (os.path.exists(path)):
    plt_metrices(path)

# %%
from Models.ModifiedNet import MNet

model = MNet().to(device)

# %%
import os.path

path = OUT_DIR+ "mnet/"+ "best_metric_model.pth"

if (os.path.exists(path)):
    model.load_state_dict(torch.load(
        os.path.join(path)))
# model.eval()

# %% [markdown]
# ## UNet 3+

# %%
from utils.view import  plt_metrices

path = OUT_DIR+ "unet_3plus/"
if (os.path.exists(path)):
    plt_metrices(path)

# %%
from Models.Unet_TriplePlus import U_net_TriplePlus

model = U_net_TriplePlus(1,1).to(device=device)

# %%
import os.path

path = OUT_DIR+ "unet_3plus/"+ "best_metric_model.pth"

if (os.path.exists(path)):
    model.load_state_dict(torch.load(
        os.path.join(path)))
# model.eval()

# %% [markdown]
# # Plot

# %%
spatial_size = [128,128,16]

# %%
sw_batch_size = 4
roi_size = spatial_size
with torch.no_grad():
    test_patient = first(test_loader)
    t_volume = test_patient['image']
    #t_segmentation = test_patient['seg']
    
    test_outputs = sliding_window_inference(t_volume.to(device), roi_size, sw_batch_size, model)
    sigmoid_activation = Activations(sigmoid=True)
    test_outputs = sigmoid_activation(test_outputs)
    test_outputs = test_outputs > 0.8
        
    for i in range(spatial_size[2]):
        # plot the slice [:, :, 80]
        plt.figure("check", (18, 6))
        plt.subplot(1, 3, 1)
        plt.title(f"image {i}")
        plt.imshow(test_patient["image"][0, 0, :, :, i], cmap="gray")
        plt.subplot(1, 3, 2)
        plt.title(f"label {i}")
        plt.imshow(test_patient["label"][0, 0, :, :, i] != 0)
        plt.subplot(1, 3, 3)
        plt.title(f"output {i}")
        plt.imshow(test_outputs.detach().cpu()[0, 0, :, :, i])
        plt.show()
